# %%
# -*- coding: utf-8 -*-
"""Complex_Assignement.ipynb

Automatically generated by Colaboratory.

Original file is located at
    https://colab.research.google.com/drive/1IS_CNlNYJuVDKrvaQyBVuPbaZR0Ka5eS
"""

#Declare a complex number and store it in a variable. 

comp_num = 4 + 5j

#Check the type and print the id of the same.

print("1.type of comp_num = 4 + 5j : ", type(comp_num))
print("1.ID   of comp_num = 4 + 5j : ", id(comp_num))

#Arithmatic Operations on complex number
#Take two different complex number.
comp_num1 = 4 + 5j
comp_num2 = 6 + 5j


#Store them in two different variables.
#Do below operations on them:-
    #Find sum of both numbers
    #Find differce between them
    #Find the product of both numbers.
    #Find value after dividing first num with second number
    #Find the result of first num to the power of second number.
    

print("2. Addition        on complex : comp_num1 +   comp_num2 : ", str(comp_num1 +  comp_num2))
print("2. Subtraction     on complex : comp_num1 -   comp_num2 : ", str(comp_num1 -  comp_num2))
print("2. Multiplication  on complex : comp_num1 *   comp_num2 : ", str(comp_num1 *  comp_num2))
print("2. Division        on complex : comp_num1 /   comp_num2 : ", str(comp_num1 /  comp_num2))
print("2. Exponent        on complex : comp_num1 **  comp_num2 : ", str(comp_num1 ** comp_num2))


#Comparison Operation not applicable between instance of complex values
#print("3. comparison        on complex : comp_num1 <   comp_num2 : ", str(comp_num1 <  comp_num2))-->TypeError: '<' not supported between instances of 'complex' and 'complex'

#Object reusability concept is not applicable on complex number

print("4.ID of comp_num1 = 4 + 5j : ", id(comp_num1))
print("4.ID of comp_num2 = 6 + 5j : ", id(comp_num2))


#Equality Operator
#Take two different complex numbers.
#Store them in two different variables.
#Equuate them using equality operator (==, !=)
#Observe the output(return type should be boolean)
print("5. Equality  on complex :  4 + 5j == 6 + 5j : ", str(4 + 5j == 6 + 5j))
print("5. Equality  on complex :  4 + 5j != 6 + 5j : ", str(4 + 5j != 6 + 5j))
#Logical operators
#Observe the output of below code
#Cross check the output manually

print(10+20j and 20+30j)    #20+30j    #----------------------------------------->Output is 20+30j
print(0+0j and 20+30j)      #0+0j    #----------------------------------------->Output is 0j
print(20+30j and 0+0j)      #0+0j   #----------------------------------------->Output is 0j
print(0+0j and 0+0j)        #0+0j   #----------------------------------------->Output is 0j

print(10+20j or 20+30j)     #10+20j   #----------------------------------------->Output is 10+20j
print(0+0j or 20+30j)       #20+30j   #----------------------------------------->Output is 20+30j
print(20+30j or 0+0j)       #20+30j  #----------------------------------------->Output is 20+30j
print(0+0j or 0+0j)         #0+0j   #----------------------------------------->Output is 0j

print(not 10+20j)           #False   #----------------------------------------->Output is False
print(not 0+0j)             #True   #----------------------------------------->Output is True

#What is the output of expression inside print statement. Cross check before running the program.
a = 10+20j
b = 10+20j
print(a is b)       #False   #True or False?
print(a is not b)   #True   #True or False?

#Membership operation
#in, not in are two membership operators and it returns boolean value

print('2.7' in 'Python2.7.8')                      #True
print(10+20j in [10,10.20,10+20j,'Python'])        #True
print(10+20j in (10,10.20,10+20j,'Python'))        #True
print(30+40j in {1,20.30,30+40j})                  #True
print(30+40j in {1:100, 2.3:200, 30+40j:300})      #True
print(10 in range(20))                             #True
# Out:
# 1.type of comp_num = 4 + 5j :  <class 'complex'>
# 1.ID   of comp_num = 4 + 5j :  2188342992752
# 2. Addition        on complex : comp_num1 +   comp_num2 :  (10+10j)
# 2. Subtraction     on complex : comp_num1 -   comp_num2 :  (-2+0j)
# 2. Multiplication  on complex : comp_num1 *   comp_num2 :  (-1+50j)
# 2. Division        on complex : comp_num1 /   comp_num2 :  (0.8032786885245902+0.16393442622950816j)
# 2. Exponent        on complex : comp_num1 **  comp_num2 :  (-390.1065660992352+676.4703509037582j)
# 4.ID of comp_num1 = 4 + 5j :  2188344103248
# 4.ID of comp_num2 = 6 + 5j :  2188344103504
# 5. Equality  on complex :  4 + 5j == 6 + 5j :  False
# 5. Equality  on complex :  4 + 5j != 6 + 5j :  True
# (20+30j)
# 0j
# 0j
# 0j
# (10+20j)
# (20+30j)
# (20+30j)
# 0j
# False
# True
# False
# True
# True
# True
# True
# True
# True
# True
